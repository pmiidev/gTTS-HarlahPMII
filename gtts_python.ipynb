# %%
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

# %%
tts = gTTS('Halo Sahabat Devo, Udah tanggal 17 April aja nich. Masih inget gak ada acara bersejarah apa? Yups, betul! Selamat Harlah Pergerakan Mahasiswa Islam Indonesia ke 62. Bersemilah-bersemilah Tunas PMII, Tumbuh subur tumbuh subur Kader PMII, Masa depan ditanganmu untuk meneruskan Perjuangan! Salam dari Lembaga Profesi Pengembang Teknologi Informasi PB PMII',lang="id")
tts.save('pmiidev.wav')
sound_file = 'pmiidev.wav'
Audio(sound_file,autoplay=True)
# Out:
#                 <audio controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
